# %%
# Install required packages
# !pip install accelerate bitsandbytes diffusers torch transformers pyexiv2 tenacity google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client

import os
import pyexiv2
from PIL import Image
import time
from tenacity import retry, stop_after_attempt, wait_exponential
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from diffusers import DiffusionPipeline
import torch
import json
from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Load the model
quantization_config = BitsAndBytesConfig(load_in_4bit=True)
tokenizer = AutoTokenizer.from_pretrained("/kaggle/input/gemma/transformers/1.1-2b-it/1/")
model = AutoModelForCausalLM.from_pretrained(
    "/kaggle/input/gemma/transformers/1.1-2b-it/1/",
    quantization_config=quantization_config
)
model.eval()

# Set up Stable Diffusion pipeline
import time
from diffusers import DiffusionPipeline
from requests.exceptions import ReadTimeout, ConnectionError

def load_pipeline_with_retries(model_id, retries=3, delay=5):
    for attempt in range(retries):
        try:
            pipeline = DiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
            return pipeline
        except (ReadTimeout, ConnectionError) as e:
            print(f"Attempt {attempt + 1} failed: {e}. Retrying in {delay} seconds...")
            time.sleep(delay)
    raise Exception(f"Failed to load the model {model_id} after {retries} attempts.")

# Usage
model_id = "stabilityai/stable-diffusion-xl-base-1.0"
pipeline = load_pipeline_with_retries(model_id)
if torch.cuda.is_available():
    pipeline.to("cuda")
    pipeline.enable_attention_slicing()
    model.to("cuda")
    print("Using CUDA")
else:
    print("Using CPU")

# Define helper functions
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt")
    if torch.cuda.is_available():
        inputs = inputs.to("cuda")
    
    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=max_length, num_return_sequences=1, temperature=0.7, do_sample=True)
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

def clear_folder(folder_path):
    for file in os.listdir(folder_path):
        os.remove(os.path.join(folder_path, file))
    print("Folder cleared successfully.")

def generate_prompts(keywords, num_prompts):
    prompts = []
    keyword_string = ", ".join(keywords)
    base_prompt = f"Generate a detailed and creative image prompt based on these keywords: {keyword_string}. The prompt should be:"
    
    while len(prompts) < num_prompts:
        generated_text = generate_text(base_prompt, max_length=100)
        clean_prompt = generated_text.replace(base_prompt, "").strip()
        if clean_prompt and clean_prompt not in prompts:
            prompts.append(clean_prompt)
    
    return prompts

def generate_keywords(prompt):
    base_prompt = f"Generate 30 relevant, simple keywords for this image prompt, separated by commas: {prompt}\nKeywords:"
    generated_text = generate_text(base_prompt, max_length=200)
    keywords = generated_text.replace(base_prompt, "").strip().split(',')
    keywords = [keyword.strip() for keyword in keywords if keyword.strip()]
    keywords.append('_ai_generated')
    return keywords

def generate_title(prompt):
    base_prompt = f"Generate a simple, catchy, and detailed title (less than 100 characters) for an image based on this prompt: {prompt}\nTitle:"
    generated_text = generate_text(base_prompt, max_length=100)
    return generated_text.replace(base_prompt, "").strip()

def upscale_and_save_image(image, jpg_path, min_file_size=500*1024):
    width, height = image.size
    scale_factor = 4
    quality = 95

    while True:
        new_size = (width * scale_factor, height * scale_factor)
        upscaled_image = image.resize(new_size, resample=Image.BICUBIC)
        upscaled_image.save(jpg_path, format="JPEG", quality=quality)

        if os.path.getsize(jpg_path) >= min_file_size:
            break

        if scale_factor < 8:
            scale_factor += 1
        elif quality < 100:
            quality += 5
        else:
            print(f"Warning: Unable to reach {min_file_size/1024}KB for {jpg_path} even after significant upscaling.")
            break

    return upscaled_image

@retry(stop=stop_after_attempt(5), wait=wait_exponential(multiplier=1, min=4, max=10))
def generate_image(pipeline, prompt):
    return pipeline(prompt).images[0]

# Google Drive API setup
def authenticate_drive_service(credentials_file):
    credentials = service_account.Credentials.from_service_account_file(credentials_file)
    drive_service = build('drive', 'v3', credentials=credentials)
    return drive_service

def upload_file_to_drive(drive_service, file_path, folder_id):
    file_metadata = {'name': os.path.basename(file_path), 'parents': [folder_id]}
    media = MediaFileUpload(file_path, resumable=True)
    file = drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()
    return file.get('id')

# Main execution
if __name__ == "__main__":
    # Path to your service account JSON file
    credentials_file = "/kaggle/input/service-account-credentials/precise-braid-383214-b0cd17ce3d76.json"
    drive_service = authenticate_drive_service(credentials_file)

    # Public folder ID on Google Drive
    PUBLIC_FOLDER_ID = "1yfkEd7BjUdiAO0FuzTqxKQCyglHl_r6n"
    
    keywords = ["River landscapes", "River trekking", "Trekking", "Kayak", "River water", "Mountain river", "River rafting", "photo-realistic", "3d render"]
    
    output_folder = "/kaggle/working/generated_images"
    os.makedirs(output_folder, exist_ok=True)
    
    print("Clearing the folder...")
    clear_folder(output_folder)

    num_prompts = 100
    prompts = generate_prompts(keywords, num_prompts)
    print(f"Generated {len(prompts)} prompts:")
    for i, prompt in enumerate(prompts, 1):
        print(f"{i}. {prompt}")

    prompt_titles = {}

    for prompt in prompts[:]:
        prompt = prompt.replace('.', '')

        try:
            keywords = generate_keywords(prompt)
            title = generate_title(prompt)
            prompt_titles[prompt] = title

            print(f"Prompt: {prompt}")
            print(f"Title: {title}")

            for i in range(5):  # num_images
                try:
                    image = generate_image(pipeline, prompt)
                    temp_jpg_path = f"{output_folder}/image-{title}-{i}.jpg"
                    upscaled_image = upscale_and_save_image(image, temp_jpg_path)

                    # Add IPTC metadata
                    image_data = pyexiv2.Image(temp_jpg_path)
                    image_data.modify_iptc({
                        'Iptc.Application2.Keywords': keywords,
                        'Iptc.Application2.Headline': title
                    })
                    image_data.close()

                    # Upload to Google Drive
                    upload_file_to_drive(drive_service, temp_jpg_path, PUBLIC_FOLDER_ID)
                    print(f"Uploaded {temp_jpg_path} to Google Drive")

                except Exception as e:
                    print(f"Error generating/saving image {i+1} for prompt '{prompt}': {e}")
                    continue

        except Exception as e:
            print(f"Error processing prompt '{prompt}': {e}")
            time.sleep(30)
            continue

        time.sleep(5)

    print("Image generation and upload process completed.")
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.34.2)
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.10/site-packages (0.44.1)
# Requirement already satisfied: diffusers in /opt/conda/lib/python3.10/site-packages (0.30.3)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: pyexiv2 in /opt/conda/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.10/site-packages (8.3.0)
# Requirement already satisfied: google-auth in /opt/conda/lib/python3.10/site-packages (2.30.0)
# Requirement already satisfied: google-auth-oauthlib in /opt/conda/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: google-auth-httplib2 in /opt/conda/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: google-api-python-client in /opt/conda/lib/python3.10/site-packages (2.147.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from diffusers) (7.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from diffusers) (3.15.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from diffusers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from diffusers) (10.3.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-httplib2) (0.21.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (2024.8.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model_index.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/2.78G [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# text_encoder_2/config.json:   0%|          | 0.00/575 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/565 [00:00<?, ?B/s]
# tokenizer_2/tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer_2/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/10.3G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Using CUDA
# Clearing the folder...
# Folder cleared successfully.
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:452: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Generated 100 prompts:
# 1. **Imagine you are a photographer capturing the breathtaking beauty of a river landscape. The scene captures the energy and movement of the water, the rugged mountains reflecting in the surface, and the kayaker navigating through the currents. Capture the sense of adventure, serenity, and power
# 2. **A majestic river landscape unfolds beneath a breathtaking mountain backdrop. Sunlight filters through the water, casting shimmering reflections on the rocky riverbed and surrounding vegetation. Kayak paddlers navigate effortlessly through the swirling currents, their silhouettes outlined against the azure expanse. Majestic mountains rise in the
# 3. **A breathtaking photorealistic 3D render of a majestic mountain river flowing through a rugged and mountainous landscape. The image captures the captivating energy and power of the river, showcasing kayakers navigating through swirling rapids and through towering cliffs. The scene is illuminated by the ethereal
# 4. **Create a stunning photorealistic 3D render of a majestic river landscape captured through the lens of a kayak paddling down the mountain river. The scene should showcase the interplay between the flowing river, rugged mountain landscape, and the adventurous kayaker navigating through the challenging conditions
# 5. **A photorealistic 3D render of a majestic river landscape, captured from the perspective of a kayak gliding through the crystal-clear water. The scene is illuminated by the warm glow of sunset casting long shadows over majestic mountains towering in the distance. The foreground features
# 6. **A majestic river landscape unfolds, sculpted by the power of cascading water. Sunlight filters through the water, illuminating the lush green banks and vibrant blue river bed. A kayaker gracefully glides through the water, capturing the majestic scene with a sense of tranquility. The photo
# 7. **A river landscape bathed in golden sunlight filtering through birch trees, a kayaker paddling through a turquoise river with majestic mountain peaks towering behind.**
#
# **Additional details:**
#
# * Capture the sense of tranquility and serenity of the scene.
# * Emphasize the interplay between
# 8. **Scene:** A majestic river landscape captured in a photo-realistic 3D render. The scene captures the beauty and energy of a river trekking adventure. The foreground features a kayaker navigating through a winding mountain river, their kayak sleek and agile amidst the swirling water
# 9. **A breathtaking photo-realistic 3D render of a majestic mountain river flowing through a lush and verdant landscape, captured through the lens of a kayak gliding through the river. The scene is illuminated by the sun peeking through the trees, casting warm, golden light
# 10. **A photo-realistic 3D render of a majestic river landscape, captured from the perspective of a kayak paddling through the crystal-clear waters. Majestic mountains rise in the background, casting a tranquil and ethereal glow over the scene. The kayak maneuvers gracefully through the
# 11. **Create a photorealistic 3D render of a majestic mountain river system, capturing the beauty and adventure of river trekking. Capture the action of kayakers navigating the river, maneuvering their kayaks through the rapids and into the calmness of calmer sections. The photo should be
# 12. **A breathtaking photo-realistic 3D render of a majestic mountain river landscape. The scene captures the energy and power of the flowing water, the rugged mountain backdrop, and the excitement of river trekking. Capture the essence of trekking through rugged terrain, navigating rapids,
# 13. **Imagine a breathtaking river landscape captured through the eyes of a kayak paddler, showcasing the interplay between river water, mountains, and the power of nature. Capture the essence of trekking, adventure, and the thrill of conquering the river.**
#
# **Additional instructions:**
# 14. **A majestic river landscape captured in photo-realistic 3D render, showcasing the interplay between rugged mountain terrain and the flowing river. A kayaker gracefully navigates the rapids, capturing the energy and beauty of the river. The scene is illuminated by the warm glow
# 15. **A photo-realistic 3D render of a majestic river landscape, captured from a drone perspective. The image captures the power and beauty of a river flowing through rugged mountains, with jagged rocks and lush vegetation clinging to the river banks. A kayaker navigates
# 16. **A majestic river landscape captured through the lens of a kayak paddling down its pristine waters. Lush green banks adorned with mossy rocks and vibrant wildflowers cascade down the rocky bank, creating a breathtaking tapestry against the crystal clear river water. Sunlight filters through the water, casting shimmering
# 17. **A photorealistic 3D render of a majestic river landscape, captured from the perspective of a kayaker navigating down a rugged mountain river. The image captures the raw power and beauty of the river, the rugged landscape, and the kayaker's determined spirit
# 18. **A photo-realistic 3D render of a majestic mountain river landscape, capturing the energy and excitement of river trekking. The image should showcase a kayaker navigating down the river, capturing the flow and speed of the water, the rugged mountain terrain, and the
# 19. **Imagine a breathtaking photorealistic 3D render of a majestic river landscape, captured during a trekking expedition. The river winds its way through towering mountains, creating a breathtaking tapestry of water, rock, and lush vegetation. A kayaker glides effortlessly through the crystal-
# 20. **A majestic 3D rendered photorealistic image of a river landscape featuring rugged mountains flanking the river, with a kayaker gracefully navigating through the rapids. The scene captures the tranquility and power of nature, with crystal-clear water reflecting the surrounding mountains and lush greenery
# 21. **A majestic river landscape bathed in the ethereal glow of moonlight, with towering mountains flanking the riverbanks. A kayaker gracefully navigates the currents, capturing the tranquility of the river and the rugged beauty of the surroundings.**
#
# **Additional details:**
#
# * The image
# 22. **A breathtaking image depicting a majestic river landscape captured through the lens of a kayaker. The photograph captures the raw power and beauty of the cascading mountain river, with crystal-clear water, rugged rock formations, and a sky tinged with shades of blue and grey.
# 23. **Imagine a breathtaking photo-realistic 3D render of a majestic mountain river flowing through a lush valley. The image captures the exhilarating feeling of trekking through the river, navigating through rapids and enjoying the refreshing water. Capture the interplay between kayakers gliding effortlessly through the
# 24. **Prompt:**
#
# **A majestic river landscape unfolds beneath a vibrant sky, showcasing towering mountains, sparkling river water, and kayakers navigating through the currents. Capture the essence of trekking and adventure through the interplay of nature, sunlight, and reflections on the water's
# 25. **A breathtaking photorealistic 3D render of a majestic river landscape captured through the lens of a kayak paddling through crystal-clear river water. The scene depicts a majestic mountain river meandering through a lush valley with towering mountains flanking the banks. The foreground shows a
# 26. **A photorealistic image of a majestic mountain river flowing through a rugged and mountainous landscape. The image captures the rugged beauty of the river and the surrounding mountains, creating a sense of grandeur and adventure. Capture the essence of trekking, kayaking, and rafting on the river
# 27. **Image Prompt:**
#
# **A 3D photorealistic image of a majestic mountain river nestled amidst towering mountains and cascading through a lush green valley. The river is crystal clear, reflecting the sunlight and setting sun. A kayaker gracefully navigates the water, exploring
# 28. **Prompt:**
#
# **Realistic 3D render of a captivating trekking adventure on a towering mountain river. The image captures the breathtaking beauty of a cascading river plunging down rocky cliffs, illuminated by the golden glow of sunset. The foreground features a kayaker gracefully navigating the
# 29. **A breathtaking photorealistic 3D render of a majestic river landscape, captured in a photo-realistic style. The scene depicts a kayaker gracefully navigating through a twisting mountain river, surrounded by towering mountains, lush vegetation, and reflective river water. Capture the sense
# 30. **A photorealistic 3D render of a majestic mountain river flowing through a rugged mountain landscape. The river is crystal clear, reflecting the sky and mountains in a vibrant array of colors. A kayaker gracefully navigates through the water, capturing the power and beauty
# 31. **A breathtaking photorealistic 3D render of a majestic river landscape captured during a trekking expedition. The scene depicts a kayak slicing through crystal-clear water, navigating through a rugged mountain river, with dramatic cliffs towering on both sides. The photo captures the essence of
# 32. **A photorealistic 3D render of a majestic mountain river landscape, captured from a kayak perspective. The image captures the power and beauty of the flowing river, the rugged mountain backdrop, and the sense of tranquility and adventure in the foreground. Capture the essence of
# 33. **Prompt:**
#
# **A breathtaking photorealistic 3D render of a majestic mountain river flowing through a rugged mountain landscape. The image captures the power and beauty of nature, showcasing the rugged cliffs, cascading waterfalls, and swirling river water. The foreground features a kay
# 34. **A photorealistic 3D render of a majestic river landscape captured from a high vantage point. The scene features a kayaker navigating through a mountain river, gracefully maneuvering their kayak through the swirling rapids and serene river water. The scene captures the power and beauty of
# 35. **Concept:** Capture the essence of a breathtaking river landscape captured through the lens of a kayak paddling down a majestic mountain river. Capture the interplay between nature, the human element, and the power of the water in a photorealistic 3D render.
#
# **Additional
# 36. **Imagine a photo-realistic 3D render of a majestic mountain river flowing through a rugged riverbed. The river is spanned by a towering mountain in the foreground, creating a dramatic and awe-inspiring composition. The kayak cuts through the water, carrying the photographer
# 37. **Imagine a majestic river landscape captured in 3D render, showcasing the beauty of mountain peaks rising majestically into the sky, meandering river waters, and kayakers navigating through the emerald waters. Capture the sense of tranquility and adventure intertwined in this stunning photograph
# 38. **Create a photorealistic 3D render of a majestic mountain river landscape captured from above, showcasing a kayaker navigating through the swirling currents of the river. Capture the sense of adventure, grandeur, and power of the flowing water and the rugged beauty of the mountain
# 39. **A majestic river landscape unfolds, sculpted by rugged mountains and cascading waterfalls. A kayaker gracefully navigates the crystal-clear water, capturing the majesty of the cascading falls and the rugged riverbed. Capture the photo-realistic, 3D render aesthetic, with
# 40. **A majestic river landscape captured through the lens of a kayak, showcasing the interplay between the flowing river, jagged mountains, and vibrant river water. Capture the sense of adventure, exploration, and tranquility found in this stunning photographic composition.**
#
# **Additional instructions:**
#
# *
# 41. **A photorealistic 3D render of a majestic river landscape captured through the lens of a kayaking adventurer. The image captures the beauty and power of a mountain river, showcasing the interplay between water, rock, and mountains. The foreground shows a kayaker gracefully navigating
# 42. **Concept:** Capture the essence of a photo-realistic river landscape featuring rugged mountains flanking the river, kayakers navigating through crystal-clear water, and the vibrant colors of the river and surrounding mountains. Capture the sense of adventure and tranquility found in this natural setting.
# 43. **A breathtaking photorealistic 3D render of a majestic river landscape captured through the lens of a kayak paddling down its currents. The scene captures the rugged beauty of a mountain river, with towering cliffs, rushing river water, and lush vegetation lining the banks. The
# 44. **Imagine a photorealistic 3D render of a majestic mountain river flowing through a breathtaking river landscape. The river is crystal clear, reflecting the mountainside in a shimmering turquoise glow. The water flows with a gentle grace, creating ripples in the surface that dance like
# 45. **A photorealistic 3D rendering of a mountain river landscape captured from the perspective of a kayaker navigating through the river rapids. The scene captures the energy and excitement of the rapids, with spray and splashes cascading over the kayak and the sense of freedom and exhilar
# 46. **A majestic river landscape unfolds before the viewer, capturing the essence of adventure and tranquility. A kayaker glides effortlessly through the crystal-clear waters, navigating the rugged terrain and majestic mountain peaks. The photo-realistic render captures the intricate details of the river, water
# 47. **A photo-realistic 3D render of a majestic mountain river flowing through a rugged mountain landscape, capturing the energy and power of the river and the ruggedness of the terrain. The image should showcase a kayaker navigating the river, gracefully gliding through the water
# 48. **Create a photorealistic 3D render of a majestic mountain river flowing through a breathtaking river landscape. The image captures the captivating energy and power of the river, showcasing the rugged mountain terrain and the kayakers navigating the rapids with grace and determination. Capture the sense
# 49. **A majestic river landscape unfolds, bathed in the ethereal glow of twilight. Sunlight streams through towering mountains, casting long shadows across the water's surface. Kayaking through the crystal-clear water, the intrepid adventurer navigates the currents, their paddle carving through the
# 50. **A photo-realistic 3D render of a majestic river landscape captured from a high vantage point, revealing the interplay between kayaking, river water, mountains, and the soaring sky. The image captures the sense of adventure, tranquility, and power of nature.**
# 51. **A majestic river landscape unfolds, featuring towering mountains, lush greenery, and crystal-clear river water. The viewer is captured in the moment, paddling through the water in a kayak, capturing the thrill and excitement of the trek. Capture the sense of adventure, nature
# 52. **Imagine a photo-realistic 3D render of a majestic river landscape captured through the eyes of a kayaker exploring the rapids of a mountain river. The scene captures the energy and power of the water, the rugged beauty of the riverbed, and the excitement
# 53. **Concept:** Capture the breathtaking beauty and adventure of river landscapes, highlighting the unique challenge and exhilaration of river trekking. Capture the interplay between river water, mountains, and kayakers in a photo-realistic 3D render.
#
# **Technical details:**
#
# *
# 54. **A photorealistic 3D render of a majestic river landscape, captured from the perspective of a kayaker navigating along a rugged mountain river. The scene captures the power and beauty of nature, with towering mountains, lush green banks, and cascading river water. The
# 55. **A majestic river landscape captured in 3D render, showcasing the interplay between river trekking, kayaking, and mountain peaks. The image should highlight the unique perspective of a photographer capturing the confluence of these elements in a photorealistic and captivating way.**
#
# **Additional details
# 56. **A photo-realistic 3D render of a majestic mountain river flowing through lush green landscapes, showcasing the thrill of river trekking and kayaking. The image captures the rugged beauty of the mountains, the sparkling river water, and the vibrant green scenery, creating a sense
# 57. **Concept:** A breathtaking photorealistic 3D render of a river landscape captured through the lens of a kayak exploring the flowing river. The image captures the majestic beauty and power of the river, the rugged mountain terrain flanking the river, and the kayaker's
# 58. **Prompt:**
#
# **A photorealistic 3D render of a majestic mountain river landscape, captured from a high vantage point. The river flows gracefully through a rugged mountain valley, carved into soaring cliffs and towering trees. Kayakers navigate through the crystal-clear water
# 59. **A photorealistic 3D render of a majestic river landscape captured through the lens of a kayak paddling through crystal-clear river water. The image captures the breathtaking beauty of mountain rivers, with cascading waterfalls, lush vegetation, and the sun casting golden rays across the
# 60. **A photo-realistic 3D render of a majestic river landscape captured through the lens of a kayak gliding down the flowing river, capturing the interplay between the river, mountains, and sky. Highlight the sense of adventure, challenge, and beauty of this epic journey
# 61. **A breathtaking photorealistic depiction of a majestic river landscape. The image captures the essence of river trekking, showcasing the power and beauty of mountain rivers. Capture the thrill and adventure of kayaking through the flowing river, capturing the interplay between the human and nature in this breathtaking
# 62. **Create a photorealistic 3D render of a majestic mountain river nestled amidst towering mountains and lush riverbanks. The image captures the serene and rugged beauty of a trekking path running alongside the river, showcasing the power and tranquility of the flowing water. Capture the sense
# 63. **A breathtaking photo-realistic 3D render of a majestic river landscape captured through the lens of a kayak paddling through crystal-clear river water. The scene is illuminated by the golden hues of sunset casting long shadows across the rugged mountainside. The kayak cuts through
# 64. **Prompt:**
#
# **A majestic mountain river carving its way through a vast landscape of rugged mountains and cliffs. The river is crystal clear, reflecting the sunlight on its surface, and kayakers glide through the water, capturing the beauty of the scenery. The photo-
# 65. **A photorealistic 3D render of a majestic river landscape captured through the lens of a kayak paddling down a mountain river. The scene captures the grandeur and power of the river, with towering mountains rising on either side, reflecting sunlight on the water's surface
# 66. **A breathtaking photo-realistic 3D render of a majestic mountain river flowing through a rugged canyon, capturing the essence of trekking and exploration. The image captures the interplay between the flowing river, rugged canyon walls, and adventurous kayakers navigating the rapids. Capture a
# 67. **A majestic river landscape bathed in golden sunlight, captured through the lens of a kayak gliding through crystal-clear water. The majestic mountain river winds through the valley, carving a path through rugged rock formations. Sunlight filters through the river, creating a shimmering effect on the
# 68. **Concept: A majestic river landscape captured in 3D render, showcasing the thrilling experience of river trekking. The image should capture the essence of adventure, nature, and the power of the river.**
#
# **Additional elements:**
#
# * The image should be photo-
# 69. **A breathtaking photorealistic 3D render of a majestic river landscape, captured through the lens of a kayak paddling down the winding river. The scene captures the power and tranquility of the mountains, valleys, and river itself, bathed in the golden glow of sunset.
# 70. **A majestic river landscape captured in 3D render, featuring a kayaker gracefully navigating through crystal-clear river water, surrounded by towering mountains bathed in the golden hues of dawn. The image captures the serenity and excitement of river trekking, showcasing the beauty and challenge
# 71. **A stunning photo-realistic 3D render of a rugged mountain river landscape. The river is flowing through a deep, emerald valley with towering granite cliffs on either side. Trekking enthusiasts are navigating the rapids, using kayaks to navigate through the churning water. The scene
# 72. **A breathtaking photo-realistic 3D render of a majestic mountain river flowing through rugged mountain landscapes. The image captures the power and beauty of nature, showcasing the intricate details of the river, rocks, and mountains. The photograph features a kayaker gracefully navigating the
# 73. **A breathtaking panoramic image of a majestic mountain river system, captured through the lens of a photo-realistic 3D render. The image depicts a trek through the river landscape, showcasing the intricate interplay between the river and the mountains. The foreground features a kayaker
# 74. **Create a photorealistic 3D render of a majestic mountain river landscape. Capture the essence of trekking and kayaking through the water, showcasing the power and beauty of the river. Use a combination of real-world photography and 3D rendering to create a breathtaking
# 75. **A majestic river landscape speckled with rugged mountains and cascading waterfalls. A kayaker paddles through the clear water, capturing the grandeur of the scene. The photo-realistic 3D render captures the ethereal beauty and challenging nature of river trekking.**
# 76. **A breathtaking photorealistic 3D render of a majestic mountain river landscape captured through the lens of a kayak gliding through crystal-clear river water. The scene captures the energy and power of the cascading river, the rugged mountain backdrop, and the adventurous spirit of the
# 77. **A breathtaking photorealistic 3D render of a majestic mountain river flowing through a rugged mountain landscape. The image captures the power and energy of the river, the rugged cliffs, and the lush vegetation that surrounds it. Kayak paddles through the water, capturing the
# 78. **A breathtaking photo-realistic 3D render of a river landscape featuring majestic mountain peaks towering over the roaring river, kayakers gliding through the crystal clear water, and panoramic views from the cliffs. Capture the essence of adventure, tranquility, and the power of nature
# 79. **A photorealistic 3D render of a majestic mountain river landscape captured through the lens of a kayak paddling through crystal-clear water, with towering mountains flanking the river and lush foliage carpeting the banks. The kayak is sleek and maneuverable, cutting through the
# 80. **Create a captivating photo-realistic 3D render of a majestic mountain river landscape. Capture the cascading energy of the river, the rugged mountains flanking it, and the excitement of a kayaker navigating through the turquoise waters. Render the scene in a way that evokes
# 81. **A majestic river landscape captured in 3D render, showcasing a kayaker navigating through crystal-clear river water, surrounded by towering mountains and lush greenery. The scene captures the exhilarating feeling of river trekking, with rocks, rapids, and scenic views captivating the eye
# 82. **A photorealistic 3D render of a breathtaking river landscape captured in a photo-realistic style, featuring a kayaker navigating along a rugged mountain river with breathtaking views of towering mountains, cascading waterfalls, lush greenery, and a turquoise river reflecting the sunlight. The
# 83. **Concept:** Capture the essence of a majestic river landscape, showcasing the power and beauty of nature through a photo-realistic, 3D rendered image. The scene should depict a kayaker navigating down a mountain river, gracefully maneuvering their kayak through the swirling currents and
# 84. **A photorealistic 3D render of a majestic river landscape captured from a kayak perspective, showcasing the interplay of water, mountains, and the human element. The image captures the energy, dynamism, and power of the river, while also highlighting the adventurous spirit of
# 85. **Prompt:**
#
# **A majestic river landscape bathed in the ethereal glow of twilight. The scene captures the essence of adventure and tranquility, with towering mountains flanking the river and the sky ablaze with fiery hues of orange, red, and purple. A kayaker gracefully navig
# 86. **A majestic river landscape captured in breathtaking photo-realistic 3D render, showcasing adventurous river trekking with a kayaker navigating through crystal-clear river water, navigating steep cliffs and boulders. The scene is further enhanced with the inclusion of rugged mountain terrain, jagged rocks
# 87. **A breathtaking photorealistic 3D render of a majestic river landscape, captured in the spirit of adventure and exploration. The image depicts a kayaker navigating turbulent river water, their kayak slicing through waves and rapids. The foreground features towering mountains rising majestically from
# 88. **A photorealistic 3D render of a majestic river landscape, captured from a bird's-eye view, showcasing river trekking, kayaking, and rafting activities. The scene captures the energy and excitement of the water rushing over rocks and through rapids, while also
# 89. **A photo-realistic 3D render of a majestic mountain river flowing through a lush landscape, captured through the lens of a kayak paddling downstream. The image captures the serene and majestic beauty of a river trekking adventure, showcasing the power and tranquility of the flowing water
# 90. **A majestic river landscape captured in photorealistic 3D render. The image depicts a serene river meandering through rugged mountains and valleys. A kayaker glides effortlessly through the water, capturing the beauty of the cascading rapids and the lush green banks. The foreground features
# 91. **A majestic river landscape captured in photorealistic 3D render, featuring a kayaker navigating through crystal clear river water, exploring hidden waterfalls and lush river banks. The scene is illuminated by the shimmering sunlight filtering through the trees, casting a vibrant glow on the water
# 92. **Imagine a breathtaking river landscape captured in stunning photo-realistic 3D render. The scene depicts a majestic mountain river flowing through a lush green valley, flanked by towering mountains and lush vegetation. Trekking enthusiasts embark on a white-water rafting adventure along the river,
# 93. **A photo-realistic 3D render of a captivating river landscape captured through a kayak expedition. The photo captures the essence of adventure, tranquility, and the power of nature. The image showcases a mountain river flowing through a rugged canyon with towering cliffs, lush greenery
# 94. **Prompt:**
#
# **A breathtaking photorealistic 3D render of a majestic mountain river flowing through a lush green landscape. The scene captures the essence of trekking and kayaking, showcasing the power and beauty of nature. Capture the thrill of white water rafting and the rugged
# 95. **Artistic Rendering of a photorealistic 3D render of a mountain river landscape captured through the lens of a kayak. The scene captures the raw power and beauty of the river, reflecting sunlight shimmering on the water's surface and the rugged mountain backdrop. The photo
# 96. **A majestic river landscape captured in photo-realistic 3D render. A kayaker stands on the river, navigating through rapids and serene waters. The scene captures the energy and power of the river, with towering mountains flanking the river and lush greenery carpeting the
# 97. **A majestic scene of a mountain river where adventurers traverse its rugged waters on a kayak. The image should capture the thrill of the trek, the power of the river, and the breathtaking views along the way. Capture the sense of adventure, challenge, and tranquility all
# 98. **A stunning photo-realistic 3D render of a majestic mountain river cascading down rugged cliffs, with a paddler navigating through the water on a kayak. The image captures the energy and flow of the water, the rugged terrain, and the adventurous spirit of the
# 99. **Create a photo-realistic 3D render of a majestic mountain river landscape. Capture the essence of trekking, kayaking, and the power of the flowing river. Use a sense of depth, texture, and light to create a breathtaking image that reflects the challenge and
# 100. **A majestic, photo-realistic 3D render of a mountain river flowing through a lush landscape, captured through the lens of a kayak gliding through its clear waters. The scene is bathed in the warm glow of sunset, casting long shadows and vibrant hues across the
# Prompt: **Imagine you are a photographer capturing the breathtaking beauty of a river landscape The scene captures the energy and movement of the water, the rugged mountains reflecting in the surface, and the kayaker navigating through the currents Capture the sense of adventure, serenity, and power
# Title: **Reflections of Adventure: A River's Embrace**
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Adventure: A River's Embrace**-0.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Adventure: A River's Embrace**-1.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Adventure: A River's Embrace**-2.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Adventure: A River's Embrace**-3.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Adventure: A River's Embrace**-4.jpg to Google Drive
# Prompt: **A majestic river landscape unfolds beneath a breathtaking mountain backdrop Sunlight filters through the water, casting shimmering reflections on the rocky riverbed and surrounding vegetation Kayak paddlers navigate effortlessly through the swirling currents, their silhouettes outlined against the azure expanse Majestic mountains rise in the
# Title: **Reflections of Majesty**
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Majesty**-0.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Majesty**-1.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Majesty**-2.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Majesty**-3.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Reflections of Majesty**-4.jpg to Google Drive
# Prompt: **A breathtaking photorealistic 3D render of a majestic mountain river flowing through a rugged and mountainous landscape The image captures the captivating energy and power of the river, showcasing kayakers navigating through swirling rapids and through towering cliffs The scene is illuminated by the ethereal
# Title: **Dancing Waters**
#   0%|          | 0/50 [00:00<?, ?it/s]
# Uploaded /kaggle/working/generated_images/image-**Dancing Waters**-0.jpg to Google Drive
#   0%|          | 0/50 [00:00<?, ?it/s]
